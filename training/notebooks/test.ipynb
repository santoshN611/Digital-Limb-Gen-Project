# %%
# !pip install nibabel matplotlib -q
import nibabel as nib, numpy as np, pathlib, matplotlib.pyplot as plt
import os
print(os.getcwd())

nii = nib.load("../../data/ImagesTr/case002_ct.nii.gz")  
vol = nii.get_fdata()  
plt.imshow(vol[vol.shape[0]//2]); plt.title(nii.shape)
for i in range(nii.shape[2]):
    plt.imshow(vol[:,:,i]); plt.title(i); plt.show()
# Out:
# c:\Users\eagle\OneDrive\Documents\Projects\Digital-Limb-Gen-Project\Digital-Limb-Gen-Project\training\notebooks
